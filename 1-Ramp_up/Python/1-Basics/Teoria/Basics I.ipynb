# %% [markdown]
# ![imagen](img/python.jpg)

# %% [markdown]
# # Python Basics I
#
# #### Author: David Miró Asensi
#
# Welcome to your first encounter with Python. In this notebook you will find the first steps to start familiarizing yourself with this language.
#
# 1. [Variables](#1.-Variables)
# 2. [Print](#2.-Print)
# 3. [Comments](#3.-Comments)
# 4. [Execution Flow](#4.-Execution-Flow)
# 5. [Del](#5.-Del)
# 6. [Data Types](#6.-Data-Types)
# 7. [Type Conversion](#7.-Type-Conversion)
# 8. [Input](#8.-Input)
# 9. [None](#9.-None)
# 10. [Syntax and Best Practices](#10.-Syntax-and-Best-Practices)
# 11. [Summary](#11.-Summary)

# %% [markdown]
# ## 1. Variables
# We start our Python adventure by declaring variables. What is this and what is it for? It's simply a way to label the data in your program. We'll start by declaring very simple variables, such as numbers and text, but we'll end up implementing more complex structures.
#
#
# ### Numeric Variables

# %%
incomes = 1000
bills = 400

# %%
print(incomes)
# Out:
# 1000

# %% [markdown]
# **This is an assignment**. To the word *income*, we assign a value using `=`.
# If we want to see the value of the variable, we simply write its name in a cell.

# %%
incomes
bills
# Out:
# 400

# %%
print(incomes)
print(bills)
# Out:
# 1000
# 400

# %% [markdown]
# ### Text Strings
# Text strings are declared with single or double quotes

# %%
text = "This text is between double quotes"
text
# Out:
# 'This text is between double quotes'

# %% [markdown]
# ##### Python is a dynamic language, so we can always update the values of variables.
# ##### It is recommended to use descriptive names when declaring variables, but not excessively long.
# ##### This way we avoid overwritting them by mistake.

# %% [markdown]
# ##### On the other hand, be careful with the characters L and one (1 vs L), as well as zero and O (O vs 0). They are often confused.

# %% [markdown]
# ##### We reassign a value to expenses

# %%
bills = 200

# %%
bills
# Out:
# 200

# %% [markdown]
# Now the expenses variable is worth 200. If the last line of a cell is a variable, its value will be the *output* of the cell: 200.
#
# Okay, what's the use of saving variables?
#
# We can use this data later, elsewhere in the program. For example, if now in a new cell we want to get the profit, we simply subtract the variable names

# %%
bills = 100

# %%
print(bills)
# Out:
# 100

# %%
benefit = incomes - bills
benefit
# Out:
# 900

# %% [markdown]
# The `print` is used to see the output of the cell, printing values to the screen. We'll see this in the next section.
#
# If you've programmed in other languages, you'll notice that in Python you don't have to specify the types of data when you declare a variable. We don't have to tell Python that *income* is a numeric value or that *income_text* is a text string. Python interprets it and knows what type of data they are. Each variable has its data type because **Python is a strongly typed language**. We'll see this later, in the *Data Types* section.

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/error.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>ERRORS in Variables</h3>
#
#  </td></tr>
# </table>

# %% [markdown]
# ### Misspelling the name
# A typical error when declaring variables is **typing their name wrong, or calling the variable later incorrectly**. In that case, a `NameError: name 'variable_that_does_not_exist' is not defined` appears

# %%
bill
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 bill
#
# NameError: name 'bill' is not defined

# %% [markdown]
# Note that it tells you the line where the error occurs, the type of error (`NameError`), and a brief description of the error.

# %% [markdown]
# ### Closing Strings Properly
# Be careful also when defining a text string, and we forget to close it with its corresponding quotes. It will give us a `SyntaxError: EOL while scanning string literal` (End Of Line)

# %%
text = "Error without quotes
text
# Out:
#   Cell In[5], line 1
#     text = "Error without quotes
#            ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# ### No Spaces in Variable Names
# It will also give an error if you have a space in the variable declaration. It's recommended to use lowercase and underscores to simulate spaces.
#
# **The spaces you find around the equals sign can be used perfectly**. It's purely aesthetic when reading the code.

# %%
new var = "variable"
# Out:
#   File "<ipython-input-32-ad2030cc1216>", line 1
#     new var = "variable"
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Numbers in Variable Names
# Be careful with numbers when declaring variables. Sometimes it's important to describe our variable with some number. In that case, always put it at the end of the variable name, otherwise it will throw an error.

# %%
incomes_2009 = 900
incomes_2009
# Out:
# 900

# %%
2009_incomes
# Out:
#   File "<ipython-input-35-87fff1b6285c>", line 1
#     2009_ingresos
#         ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ### Case Sensitive
# Be very careful with uppercase and lowercase letters because Python doesn't ignore them. If all the letters of a variable are uppercase, you will have to use it in uppercase, otherwise it will give an error that the variable is not found.

# %%
incomes_2009 = 900
incomes_2009
# Out:
# 900

# %%
Incomes_2009
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MIGUEL~1\AppData\Local\Temp/ipykernel_6396/2887449943.py in <module>
# ----> 1 Ingresos_2009
#
# NameError: name 'Ingresos_2009' is not defined

# %% [markdown]
# ### Reserved Words
# In Python, as in other languages, there are a series of reserved words that have a meaning for the Python interpreter and therefore we cannot use them to name our variables.
#
# For example, `def` is used to define functions in Python (we'll see this in other notebooks), so we cannot use `def` to name our variables

# %%
def = 9
# Out:
#   File "<ipython-input-3-0e34f8701d38>", line 1
#     def = 9
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# Check the list of Python reserved words

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %% [markdown]
# ### Variables Summary
# In summary:
# * Use lowercase. Case sensitive
# * Don't use spaces
# * Don't use reserved words
# * Don't use numbers at the beginning of the variable
# * Be careful with the characters `l`, `1`, `O`, `0`

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/ejercicio.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>Exercise Variables</h3>
#
#
# <ol>
#     <li>Create a program that stores your name and your last names in two different variables.</li>
#     <li>Save your age in another variable</li>
#     <li>Modify the variable with your age</li>
#     <li>Verify that all variables have the values that correspond to them</li>
# </ol>
#
#  </td></tr>
# </table>

# %%
first_name = "arvind"
last_name = "uday" 
age_2026 = "29" 
age_2026 = "18"

# %%
print(first_name)
print(last_name)
print(age_2026)
# Out:
# arvind
# uday
# 18

# %% [markdown]
# ## 2. Print

# %% [markdown]
# So far we've seen two types of cells in Jupyter:
# * **Markdown**: basically text for explanations
# * **Code**: where we insert Python code and execute it
#
# Code cells not only run the code and perform all the operations we tell it to, but they also have an output, an output from that code. We have two options to see the output of the code, either through `print`, or by putting a variable at the end of the cell. In the latter case, we will see the value of that variable

# %%
print(incomes)
print(bills)
print("The benefits have been:",incomes - bills)
benefit = incomes - bills
print(benefit)
# Out:
# 1000
# 100
# The benefits have been: 900
# 900

# %% [markdown]
# If we print a text, we can concatenate variable values using `%s`.

# %%
print('The benefits for June have been 800 million')
# Out:
# The benefits for June have been 800 million

# %%
print("The benefits for %s have been %s million" % ("June",benefit))
# Out:
# The benefits for June have been 900 million

# %%
print("have been " + benefit + " millions")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-b21feb4d56bc> in <module>
# ----> 1 print("de " + beneficios + " millones")
#
# TypeError: can only concatenate str (not "int") to str

# %%
print("have been " + str(benefit) + " millions")
# Out:
# de 900 millones

# %% [markdown]
# Another option if we want to print multiple strings to the screen is by separating them by commas in the `print`. Notice that it adds spaces to the output each time we put a new value between commas.

# %%
month = "August"
print("The benefits for", month, "have been", benefit, "million")
# Out:
# The benefits for August have been 900 million

# %%
"The benefits for August have been 900 million"
# Out:
# 'The benefits for August have been 900 million'

# %%
print(f"The benefits for {month} have been {benefit} million")
# Out:
# Los beneficios de 19200 han sido de 900 millones

# %% [markdown]
# ## 3. Comments
# These are text that goes along with the code, and which the Python interpreter completely ignores. Very useful for documenting and explaining code

# %%
# One-line comment
# print("The interpreter ignores this")

print("this it does execute")  # I can also put a comment here

'''
Multi-line
comment
'''

"""
Multi-line
comment
"""

print("End of program")
# Out:
# this it does execute
# End of program

# %% [markdown]
# **IMPORTANT**. ALWAYS comment your code. You never know who might inherit it. I leave you in [this link](https://realpython.com/python-comments-guide/) an interesting guide on how to comment your code.

# %% [markdown]
# ## 4. Execution Flow
# Python programs execute sequentially, so the order in which you write operations is determinant

# %%
sales_june = 100
sales_july = 150

sales_jun_jul = sales_june + sales_july
print(sales_jun_jul)
# Out:
# 250

# %%
sales_jun_jul
# Out:
# 250

# %%
sales_may_april = sales_may + sales_april

sales_may = 100
sales_april = 150
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-114-6e0a60dc2914> in <module>
# ----> 1 sales_may_april = sales_may + sales_april
#       2
#       3 sales_may = 100
#       4 sales_april = 150
#
# NameError: name 'sales_may' is not defined

# %% [markdown]
# **It gives an error**, first we have to declare the sales, and then add them.
#
# **When does a line of code end?**. Python interprets the line break as a new instruction. In many languages, like Java, you have to specify the end of the code statement with `;`. In Python it's not necessary, although it can be used anyway.

# %%
height = 1.80; weight = 75
print(height)

x, y, z = 1, 2, 3
print(z)
# Out:
# 1.8
# 3

# %%
x = 1
y = 2
z = 3

# %%
x = 1; y = 2; z = 3

# %% [markdown]
# ## 5. Del
# This is the statement we will use to delete a variable. The truth is, variables are not usually deleted. We develop Python programs without worrying about cleaning up those variables we don't use. Usually not deleting them is not usually a problem, but when we handle a large volume of data, we can suffer performance problems since **variables take up memory**.
#
# When the variables are the ones we've seen so far, nothing happens, but if they are heavier, like for example image datasets that take up a lot, it will be good to delete those we don't use.

# %%
print(height)
# Out:
# 1.8

# %%
del height
print(height)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MIGUEL~1\AppData\Local\Temp/ipykernel_6396/65827148.py in <module>
#       1 del altura
# ----> 2 print(altura)
#
# NameError: name 'altura' is not defined

# %% [markdown]
# ## 6. Data Types
# Python is a strongly typed language. This means that the variables we use belong to a data type: integer number (int), real (float), text (String), or another type of object.
#
# **Why is it important to know well what types the data is?** Because each data type has a series of properties and operations associated with it. For example, you cannot add 5 to text. So when we go to do operations between them, we have to make sure they are the same type so that the result is what we expect. `text + 5` doesn't make sense and will give an error. It seems obvious, but there are times when the data types are not what we expect.
#
# **How many data types are there?** Basically there are no limits here. In this notebook we will see the most basic ones, but in later notebooks you will see that you can create your own data types through **classes**. In Python there are a series of basic data types, which we can use without importing any external module, they are called [*built-in Types*](https://docs.python.org/3/library/stdtypes.html). These are the most common:
#
# * **Numeric**: we have `int`, `float` and `complex`. Depending on whether it is an integer number, a real one or a complex one.
# * **String**: or String. Plain text string
# * **Boolean**: or Logical. `True`/`False`
#
# **How do we know the data type of a variable?** Using `type(variable_name)`

# %% [markdown]
# ### Numeric

# %%
number = 22
type(number)
# Out:
# str

# %% [markdown]
# Good, it's an ***int***, an integer. If what I want is a real number, that is, that it has decimals, I add a point

# %%
real_number = 22.45
type(real_number)
# Out:
# float

# %% [markdown]
# Even though I haven't added decimals as such, I'm already telling Python that this variable is a real number (***float***).

# %%
real_number = 22.0
type(real_number)
# Out:
# float

# %% [markdown]
# Some basic operations we can do with numbers:
# * Add: `+`
# * Subtract: `-`
# * Multiply: `*`
# * Divide: `/`
# * Power: `**`
# * Division quotient: `//`
# * Division remainder: `%`

# %%
print("Addition and subtraction")
print(1 + 2)
print(1.0 + 2)
print(1.0 - 2)

print("Mult/Div")
print(2*2)
print(2.0*2)
print(2/2)

print("Division remainder")
print(10/3)
print(int(10/3))
print(10 % 3)
print(10 // 3)
# Out:
# Sumas y restas
# 3
# 3.0
# -1.0
# Mult/Div
# 4
# 4.0
# 1.0
# Resto division
# 3.3333333333333335
# 3
# 1
# 3

# %%
print(12 % 2)
# Out:
# 0

# %% [markdown]
# ### Strings
# The third most common data type is *String*, or text string. There are several ways to declare it:

# %%
string = "This is a string"
type(string)
# Out:
# str

# %%
print("First line\nSecond line\n\tThird line")
# Out:
# First line
# Second line
# 	Third line

# %% [markdown]
# To join two String type variables, we simply use `+`

# %%
name = "Bon"
surname = "Scott"
blankspace = " "

name_surname = name + blankspace + surname
name_surname
# Out:
# 'Bon Scott'

# %% [markdown]
# ### Boolean
# Finally, the fourth most basic data type is *boolean*: `True`/`False`. For Python to recognize this data type, you have to write them with the first letter in uppercase

# %%
i_know_python = True
type(i_know_python)
# Out:
# bool

# %% [markdown]
# There are many data types, you will see later how to create your own data types through **classes** and **objects**. But for now, stick with the simplest data types:
# * **int**: integer
# * **float**: real
# * **str**: text string
# * **boolean**: true/false

# %% [markdown]
# In other programming languages the numeric value is usually broken down more depending on its volume. It's not the same to have a `double` as a `float`. Fortunately in Python you don't have to worry about that :)
#
# Let's see more examples

# %%
print(type("-74"))
# Out:
# <class 'str'>

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/error.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>ERRORS in Data Types</h3>
#
#  </td></tr>
# </table>

# %%
print("It has "quotes" doubles. This is wrong")
# Out:
#   File "<ipython-input-119-f228d8afa0a5>", line 1
#     print("It has "quotes" doubles. This is wrong")
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 7. Type Conversion
# As in other languages, in Python we also have the possibility to perform conversions between data types. So far we have seen few, but when we discover more data types and objects, you will see that these transformations are very common.
#
# A very common case is reading a file with numerical data, and Python interpreting the numbers as characters. It's not an error, but later, when we do operations with our numbers, we'll have errors, since they are actually text strings. If we force the change to numeric, we'll avoid future problems.
#
# **Be very careful when changing types**. We have to be sure of what we're doing as we can lose information, or more likely, it can give an error, as the change may not be compatible.
#
# Let's see how to change the types

# %%
num_real = 24.69
print(type(num_real))

num_int = int(num_real)
print(num_int)
print(type(num_int))
# Out:
# <class 'float'>
# 24
# <class 'int'>

# %% [markdown]
# We lose some decimals, usually nothing serious, although it depends on the application.
#
# **NOTE**: if what we want is to round, we can use the `round()` function

# %%
round(24.691739372, 0)
# Out:
# 25.0

# %% [markdown]
# To go from a **number to string**, there is no problem

# %%
real = "24.69"
integer = 5

real_str = str(real)
entero_str = str(integer)

print(type(real_str))
print(real_str)
# Out:
# <class 'str'>
# 24.69

# %% [markdown]
# From **String to number** there's usually no problem either. You have to be very careful with the decimal points. **Dots, NOT commas**

# %%
my_integer, my_other_integer = 98,56

# %%
my_integer
# Out:
# 98

# %%
my_other_integer
# Out:
# 56

# %%
my_string = "98"
my_integer = int(my_string)
print(my_string)
print(type(my_string))
print(my_integer)
print(type(my_integer))
# Out:
# 98
# <class 'str'>
# 98
# <class 'int'>

# %%
print(int("98"))
print(float("98.56"))
print(float("98,56"))
# Out:
# 98
# 98.56
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-e0706caa20f9> in <module>
#       1 print(int("98"))
#       2 print(float("98.56"))
# ----> 3 print(float("98,56"))
#
# ValueError: could not convert string to float: '98,56'

# %% [markdown]
# Converting **number to boolean and vice versa** is also quite simple. Just keep in mind that 0s are `False`, and the rest of the numbers equal a `True`

# %%
print(bool(1))
print(bool(0))
# print(bool(-1.87))
# Out:
# True
# False

# %% [markdown]
# In the case of converting **String to boolean**, empty strings will be `False`, while those that have any string, will equal `True`.
#
# However, if the operation is the opposite, the `True` boolean will become a text string like `True`, and the same for `False`.

# %%
print(bool(""))
print(bool("bdskajsnlkd"))
# Out:
# False
# True

# %%
true = True
print(str(true))
print(type(str(true)))
# Out:
# True
# <class 'str'>

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/error.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>ERRORS in Type Conversion</h3>
#
#  </td></tr>
# </table>

# %% [markdown]
# Watch out if you try to convert to integer a string with the appearance of a real number. As soon as it carries the point, it has to be a real number. Unless we pass it to real and then to integer (`int()`), or using `round()` as we saw earlier

# %%
int("98.25")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\MIGUEL~1\AppData\Local\Temp/ipykernel_6396/1034181111.py in <module>
# ----> 1 int("98.25")
#
# ValueError: invalid literal for int() with base 10: '98.25'

# %% [markdown]
# If we read data with decimals and have commas instead of dots, there will be errors.

# %%
float("98,25")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-a5b818f1e655> in <module>
# ----> 1 float("98,25")
#
# ValueError: could not convert string to float: '98,25'

# %% [markdown]
# ## 7. Type Conversion
# As in other languages, in Python we also have the possibility to perform conversions between data types. So far we have seen few, but when we discover more data types and objects, you will see that these transformations are very common.
#
# A very common case is reading a file with numerical data, and Python interpreting the numbers as characters. It's not an error, but later, when we do operations with our numbers, we'll have errors, since they are actually text strings. If we force the change to numeric, we'll avoid future problems.
#
# **Be very careful when changing types**. We have to be sure of what we're doing as we can lose information, or more likely, it can give an error, as the change may not be compatible.
#
# Let's see how to change the types

# %%
number = "98,25"
print(number)

number_point = number.replace(",", ".")
print(number_point)

number_float = float(number_point)
print(type(number_float))
# Out:
# 98,25
# 98.25
# <class 'float'>

# %%
string_example = "I live in Madrid. Sure in Madrid?"

print(string_example.replace("Madrid", "Barcelona"))
# Out:
# I live in Barcelona. Sure in Barcelona?

# %% [markdown]
# It is fundamental to operate with the same data types. Look what happens when we add text with a number. It gives a `TypeError`. Basically it tells us that you can't concatenate a text with an integer

# %%
"4" + 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\MIGUEL~1\AppData\Local\Temp/ipykernel_6396/336248650.py in <module>
# ----> 1 "4" + 6
#
# TypeError: can only concatenate str (not "int") to str

# %%
6 + "4"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\MIGUEL~1\AppData\Local\Temp/ipykernel_6396/3050941067.py in <module>
# ----> 1 6 + "4"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/ejercicio.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>Exercise Data Types</h3>
#
#
# <ol>
#     <li>Create a String variable that includes double quotes</li>
#     <li>Check its type</li>
#     <li>Create another string saving it in another variable, and try to add them</li>
#     <li>Now declare an integer variable. Print it to the screen</li>
#     <li>Change the type of the integer variable to float. Print both the new variable obtained and its type</li>
# </ol>
#
#  </td></tr>
# </table>

# %%
number_one = "69"
print(type(number_one))
number_two = "96"
print (type(number_two))
print(number_one + number_two)
intiger= 3
print(intiger)
real = float(intiger)
print(real)
# Out:
# <class 'str'>
# <class 'str'>
# 6996
# 3
# 3.0

# %% [markdown]
# ## 8. Input
# This statement is used in Python to collect a value that the user of the program writes. Programs usually work that way, they receive an input, perform operations, and end up giving an output to the user.
#
# For example, in the following cell I collect an input, which we can then use in later cells.
#
# **CAUTION**. If you run a cell with an `input()` the program stays waiting for the user to enter a value. If at the time it is waiting, you run the same cell again, it can get stuck, depending on the computer/version of Jupyter. If that happens, click on the cell and then press the stop button at the top, or else go to Kernel -> Restart Kernel...

# %%
primer_input = input()

# %%
primer_input
# Out:
# 'Good Morning'

# %% [markdown]
# You can put ints, floats, strings, whatever you want to collect in plain text.
#
# Look how easy it is to make a bit silly chatbot, through which we ask the user questions, and store their answers.

# %%
name = input("What is your name?")
print("Pleased to greet you,", name)

feedback = input("What do you think of Python?")
print("I agree, It´s a joke, ", feedback)
print(feedback)
# Out:
# Pleased to greet you, aum
# I agree, It´s a joke,  great
# great

# %%
print(feedback)
# Out:
# amazing

# %%
"""
By default, the user's input is of text type. You will have to convert it to numeric with int(numero_input)
or with float(numero_input). We'll see this in the next notebook.
"""
num_input = input("Enter a number")

num_input + 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 7
#       1 """
#       2 By default, the user's input is of text type. You will have to convert it to numeric with int(numero_input)
#       3 or with float(numero_input). We'll see this in the next notebook.
#       4 """
#       5 num_input = input("Enter a number")
# ----> 7 num_input + 4
#
# TypeError: can only concatenate str (not "int") to str

# %%
num_input = int(input("Enter a number"))

num_input + 4
# Out:
# 10

# %% [markdown]
# <table align="left">
#  <tr><td width="80"><img src="img/ejercicio.png" style="width:auto;height:auto"></td>
#      <td style="text-align:left">
#          <h3>Exercise Input</h3>
#
# In this example we are going to simulate a chatbot to which we will make pizza orders.
# <ol>
#     <li>The chatbot must greet with: "Good afternoon, welcome to the online ordering service, how many pizzas do you want?"</li>
#     <li>The user must enter a number of pizzas in a variable called 'pizz'</li>
#     <li>Response from the chatbot: "Great, 'pizz' pizzas are being prepared. Tell me your address"</li>
#     <li>The user must enter an address in String format in another variable called 'direcc'</li>
#     <li>Final response from the chatbot: "We will send the 'pizz' pizzas to the address 'direcc'. Thank you for your order."</li>
# </ol>
#
#  </td></tr>
# </table>

# %%
# Chatbot for pizza orders


print("Good afternoon, welcome to the online ordering service, how many pizzas do you want?")


pizz = int(input())


print(f"Great, {pizz} pizzas are being prepared. Tell me your address")


direcc = input()


print(f"We will send the {pizz} pizzas to the address {direcc}. Thank you for your order.")
# Out:
# Good afternoon, welcome to the online ordering service, how many pizzas do you want?
# Great, 2 pizzas are being prepared. Tell me your address
# We will send the 2 pizzas to the address ram. Thank you for your order.

# %% [markdown]
# ## 9. None
# Reserved word in Python to designate the null value. `None` is not 0, nor is it an empty string, nor `False`, it's simply another data type to represent the empty set.

# %%
print(None)
print(type(None))
# Out:
# None
# <class 'NoneType'>

# %% [markdown]
# ## 10. Syntax and Best Practices
# When writing in Python, there are certain rules you need to follow:
# * Everything you open, you have to close: parentheses, braces, brackets...
# * Decimals are placed with dots `.`
# * Best practices
#     * **Characters**: It is NOT recommended to use Ñs, accents or strange characters (ª,º,@,ç...) in the code. Put it only in the comments.
#     * **Spaces**: Do NOT use spaces in the names of variables or functions. It is recommended to use an underscore to simulate the space. Or also put the words together and use a capital letter to differentiate them `myVariable`. The norm is all lowercase and underscores
#     * However, it is recommended to use spaces between each command, to facilitate reading, although this is more a matter of taste. `my_variable = 36`.
#     * Variables are usually declared in lowercase.
#     * Constants (variables that will never change) in uppercase. `MY_COUNTRY = "Spain"`
#     * **Each statement on a line**. You can use `;` to declare multiple variables, but it's not the norm
#     * **Comments**: As many as possible. You never know when someone else is going to pick up your spectacular code, or if your *future self* will remember why you did that while loop instead of a for.
#     * **Case sensitive**: sensitive to uppercase and lowercase letters. BE CAREFUL with this when declaring variables or using Strings
#     * **Line syntax**: for proper code reading, it's best to apply line syntax as much as possible

# %%
buy_list = ['Apples',
                'Cookies',
                'Chicken',
                'Cereals']
buy_list
# Out:
# ['Apples', 'Cookies', 'Chicken', 'Cereals']

# %% [markdown]
# ### The Zen of Python
# Any advice I could have given you so far pales in comparison to the 20 principles defined by *Tim Peters* in 1999. One of the greatest collaborators in the creation of this language

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ## 11. Summary

# %%
# Declare variables
var = 10

# Reassign values
var = 12

# Print to screen
print("First line")
print("Declared variable is:", var)
print("Declared variable is: %s" %(var))

"""
Multi-line
comments
"""

# Delete variables
del var

# Data types
print("\n")  # Just to have a line break in the output
print(type(1))  # Int
print(type(1.0))  # Float
print(type("1"))  # String
print(type(True))  # Boolean

# Type conversions
print("\n")
var2 = 4
print(type(var2))
var2 = str(var2)
print(type(var2))
var2 = bool(var2)
print(type(var2))

# The null value
print(None)

# Variable input
var3 = input("Insert variable ")
